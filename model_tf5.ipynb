# %% [markdown]
# # daily

# %% [markdown]
# # import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
# %matplotlib ipympl


from setup_data import setup_as_data, setup_an_data
from utils import time_period, plot_dfs

# %% [markdown]
# ## austevoll soor

# %% [markdown]
# ### Get data

# %%
Austevoll_Sor_file_path = "row_data\\Austevoll_Sor\\Austevoll_data_instrument.feather"
print(Austevoll_Sor_file_path)
Austevoll_Sor_df = pd.read_feather(Austevoll_Sor_file_path)
Austevoll_Sor_df.set_index('Time', inplace=True)
len(Austevoll_Sor_df)
# Out:
# row_data\Austevoll_Sor\Austevoll_data_instrument.feather
# 22393

# %%
len(Austevoll_Sor_df.columns)
# Out:
# 51

# %%
for col in Austevoll_Sor_df.columns:
    print(col)
# Out:
# Long
# Lat
# Doppler_Current_Profiler_Sensor.Heading
# Doppler_Current_Profiler_Sensor.Abs_Tilt
# Doppler_Current_Profiler_Sensor.Max_Tilt
# Doppler_Current_Profiler_Sensor.Record_State
# Doppler_Current_Profiler_Sensor.Ping_Count
# Conductivity_Sensor.Conductivity
# Conductivity_Sensor.Temperature
# Conductivity_Sensor.Salinity
# Conductivity_Sensor.Density
# Conductivity_Sensor.Soundspeed
# Pressure_Sensor.Pressure
# Pressure_Sensor.Temperature
# Analog_Sensors.Chlorophyll#2103755
# System_Parameters.Input_Voltage
# System_Parameters.Memory_Used
# SeaBird_SBE.Temperature
# SeaBird_SBE.Conductivity
# SeaBird_SBE.Pressure
# SeaBird_SBE.Oxygen
# SeaBird_SBE.Sound_Velocity
# Oxygen_Optode.O2Concentration
# Oxygen_Optode.AirSaturation
# Oxygen_Optode.Temperature
# Oxygen_Optode.CalPhase
# Oxygen_Optode.TCPhase
# Oxygen_Optode.C1RPh
# Oxygen_Optode.C2RPh
# Oxygen_Optode.C1Amp
# Oxygen_Optode.C2Amp
# Oxygen_Optode.RawTemp
# Temperature_Sensor.Temperature
# Temperature_Sensor.Rawdata_Temperature
# Tide_Sensor.Pressure
# Tide_Sensor.Temperature
# Tide_Sensor.Tide_Pressure
# Tide_Sensor.Tide_Level
# Conductivity_Sensor.Conductance
# Conductivity_Sensor.RawCond0
# Conductivity_Sensor.ZAmp
# Conductivity_Sensor.ExRawTemp
# Conductivity_Sensor.InRawTemp
# Conductivity_Sensor.UsedRange
# Analog_Sensors.Turbidity#16340
# Analog_Sensors.Turbidity#16340_Raw_data
# Doppler_Current_Profiler_Sensor.Std_Dev_Heading
# Doppler_Current_Profiler_Sensor.Pitch
# Doppler_Current_Profiler_Sensor.Roll
# Doppler_Current_Profiler_Sensor.Std_Dev_Tilt
# Doppler_Current_Profiler_Sensor.Tilt_Direction

# %%
r_h=24
as_list_segments = [3, 4, 5, 6, 7, 8, 9]
Austevoll_Sor_df_segments = setup_as_data(Austevoll_Sor_df, smooth_sigma=18, list_segments=as_list_segments, r_h=r_h)
# Out:
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.1552, b=15.9170, d=66.51, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.1595, b=17.1581, d=60.67, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=11.5614, b=16.9510, d=78.14, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.2295, b=16.0725, d=59.88, s=0.001000
# ✅ Fitted params: a=12.1447, b=18.2732, d=80.25, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.1479, b=15.9571, d=71.39, s=0.001000
# ✅ Fitted params: a=12.5281, b=18.9157, d=83.71, s=0.001000

# %%
Austevoll_Sor_df_segments[3].columns
# Out:
# Index(['Num_Not_Nan', 'Num_Nan', 'Num_Bytes', 'Time_Since_t0',
#        'Time_Since_t0_n', 'Hours_Since_t0', 'Days_Since_t0', 'Weeks_Since_t0',
#        'Months_Since_t0', 'year', 'month_0', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'weekday_0', 'weekday_1', 'weekday_2',
#        'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'Temperature',
#        'Temperature_sum', 'sin_month', 'cos_month', 'sin_week', 'cos_week',
#        'sin_day', 'cos_day', 'sin_hour', 'cos_hour',
#        'System_Parameters.Input_Voltage', 'Battery_Level_Fitted',
#        'Battery_Level_Derivative', 'Voltage_Lag1', 'Voltage_Lead1',
#        'Voltage_Diff', 'Voltage_Change_Rate', 'Rolling_Mean_Voltage',
#        'Rolling_Max_Voltage', 'Rolling_Std_Voltage'],
#       dtype='object')

# %%
from utils import time_period

#6,4,3,8 
# period for all segments
for i in range(len(as_list_segments)):
    print(f"segment {as_list_segments[i]}: {time_period(Austevoll_Sor_df_segments[as_list_segments[i]])}")
# Out:
# segment 3: (1, 28, 0, 0, 0)
# segment 4: (1, 22, 0, 0, 0)
# segment 5: (2, 10, 0, 0, 0)
# segment 6: (1, 22, 0, 0, 0)
# segment 7: (2, 12, 0, 0, 0)
# segment 8: (2, 3, 0, 0, 0)
# segment 9: (2, 14, 0, 0, 0)

# %%
Austevoll_Sor_df_segments[3].columns
# Out:
# Index(['Num_Not_Nan', 'Num_Nan', 'Num_Bytes', 'Time_Since_t0',
#        'Time_Since_t0_n', 'Hours_Since_t0', 'Days_Since_t0', 'Weeks_Since_t0',
#        'Months_Since_t0', 'year', 'month_0', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'weekday_0', 'weekday_1', 'weekday_2',
#        'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'Temperature',
#        'Temperature_sum', 'sin_month', 'cos_month', 'sin_week', 'cos_week',
#        'sin_day', 'cos_day', 'sin_hour', 'cos_hour',
#        'System_Parameters.Input_Voltage', 'Battery_Level_Fitted',
#        'Battery_Level_Derivative', 'Voltage_Lag1', 'Voltage_Lead1',
#        'Voltage_Diff', 'Voltage_Change_Rate', 'Rolling_Mean_Voltage',
#        'Rolling_Max_Voltage', 'Rolling_Std_Voltage'],
#       dtype='object')

# %% [markdown]
# ### concatinate ausevold soor data

# %%
plot_dfs([Austevoll_Sor_df_segments[7][['Time_Since_t0']]])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## adding more features

# %%
def process_segment(df):
    """
    Process a single segment DataFrame.
    No resetting index — use index as datetime.
    Adds voltage over time and ht feature too.
    """
    df = df.copy()
    
    # Compute time elapsed in seconds from start (use index)
    df['time_seconds'] = (df.index - df.index[0]).total_seconds()
    
    # Derivative of voltage (how fast voltage is dropping/rising)
    df['dV_dt'] = df['System_Parameters.Input_Voltage'].diff() / df['time_seconds'].diff()
    df['dV_dt'].fillna(0, inplace=True)
    
    
    # Rolling mean of voltage (to smooth out noise)
    df['voltage_roll5'] = df['System_Parameters.Input_Voltage'].rolling(window=10, min_periods=1).mean()
    
    # Voltage over time: normalized voltage decay
    initial_voltage = df['System_Parameters.Input_Voltage'].iloc[0]
    df['voltage_over_time'] = df['System_Parameters.Input_Voltage'] / initial_voltage


    
    # Health ht feature: 1 if voltage > 11.65, else 0
    df['ht'] = (df['System_Parameters.Input_Voltage'] > 11.5).astype(float)
    
    
    df['temp_cos'] = np.cos(df.index.dayofyear * (2 * np.pi / 365))
    df['temp_sin'] = np.sin(df.index.dayofyear * (2 * np.pi / 365))

    return df




for i, df in Austevoll_Sor_df_segments.items():
    processed_df = process_segment(df)
    Austevoll_Sor_df_segments[i] = processed_df
# Out:
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_15452\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)

# %%
as_df = pd.concat([
    #Austevoll_Sor_df_segments[1].copy(),
    #Austevoll_Sor_df_segments[2].copy() 
    Austevoll_Sor_df_segments[3].copy(),
    Austevoll_Sor_df_segments[4].copy(),
    Austevoll_Sor_df_segments[5].copy(),
    Austevoll_Sor_df_segments[6].copy(),
    Austevoll_Sor_df_segments[7].copy(),
    Austevoll_Sor_df_segments[8].copy(),
    Austevoll_Sor_df_segments[9].copy()
    #Austevoll_Sor_df_segments[10].copy()
])

# %%
plot_dfs([as_df[['System_Parameters.Input_Voltage', 'Battery_Level_Fitted',]]])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
as_df.reset_index(inplace=True)
as_df.head(1)
# Out:
#         Time  Num_Not_Nan  Num_Nan  Num_Bytes  Time_Since_t0  Time_Since_t0_n  \
# 0 2023-03-01         20.0     29.0      208.0            0.0              0.0
#
#    Hours_Since_t0  Days_Since_t0  Weeks_Since_t0  Months_Since_t0  ...  \
# 0             0.0              0               0                0  ...
#
#    Rolling_Mean_Voltage  Rolling_Max_Voltage  Rolling_Std_Voltage  \
# 0               12.3254              12.3254                  NaN
#
#    time_seconds  dV_dt  voltage_roll5  voltage_over_time   ht  temp_cos  \
# 0           0.0    0.0        12.3254                1.0  1.0  0.512371
#
#    temp_sin
# 0  0.858764
#
# [1 rows x 57 columns]

# %%
as_df.columns
# Out:
# Index(['Time', 'Num_Not_Nan', 'Num_Nan', 'Num_Bytes', 'Time_Since_t0',
#        'Time_Since_t0_n', 'Hours_Since_t0', 'Days_Since_t0', 'Weeks_Since_t0',
#        'Months_Since_t0', 'year', 'month_0', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'weekday_0', 'weekday_1', 'weekday_2',
#        'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'Temperature',
#        'Temperature_sum', 'sin_month', 'cos_month', 'sin_week', 'cos_week',
#        'sin_day', 'cos_day', 'sin_hour', 'cos_hour',
#        'System_Parameters.Input_Voltage', 'Battery_Level_Fitted',
#        'Battery_Level_Derivative', 'Voltage_Lag1', 'Voltage_Lead1',
#        'Voltage_Diff', 'Voltage_Change_Rate', 'Rolling_Mean_Voltage',
#        'Rolling_Max_Voltage', 'Rolling_Std_Voltage', 'time_seconds', 'dV_dt',
#        'voltage_roll5', 'voltage_over_time', 'ht', 'temp_cos', 'temp_sin'],
#       dtype='object')

# %% [markdown]
# ## model training

# %%
list_features = ['Time', 'Num_Not_Nan', 'Num_Nan', 'Num_Bytes', 
                 
                 'Time_Since_t0',
       'Time_Since_t0_n','Hours_Since_t0', 'Days_Since_t0', 'Weeks_Since_t0',
       'Months_Since_t0', 
       
       'year', 'month_0', 'month_1', 'month_2', 'month_3',
       'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
       'month_10', 'month_11', 'weekday_0', 'weekday_1', 'weekday_2',
       'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 
       
       'Temperature',
       'Temperature_sum', 'sin_month', 'cos_month', 'sin_week', 'cos_week',
       'sin_day', 'cos_day', 'sin_hour', 'cos_hour',
       
       
       'System_Parameters.Input_Voltage', 
       'Battery_Level_Fitted',        # y
       'Battery_Level_Derivative', 
       
       'Voltage_Lag1', 'Voltage_Lead1',
       'Voltage_Diff', 'Voltage_Change_Rate', 'Rolling_Mean_Voltage',
       'Rolling_Max_Voltage', 'Rolling_Std_Voltage', 
       
       'time_seconds',
       'voltage_roll5', 'voltage_over_time', 'ht', 'temp_cos', 'temp_sin']




features =  [
        #'Hours_Since_t0',
       'Days_Since_t0',
        #'Weeks_Since_t0',
        
        #'dV_dt',
        #'voltage_roll5',
        
         #'voltage_over_time',
        'ht',
        
        #'temp_cos',
        #'temp_sin',
        
        #'Voltage_Lead1',
        #'Battery_Level_Fitted'
        
        #'Voltage_Lag1',
       #'Voltage_Diff', 
       #'Voltage_Change_Rate', 
       #'Rolling_Mean_Voltage',
       #'Rolling_Max_Voltage', 
       # 'Rolling_Std_Voltage', 
       
       #'Battery_Level_Fitted',
       #'System_Parameters.Input_Voltage', 
        
        ]

target = 'System_Parameters.Input_Voltage'

# %%
X_y = features + [target]
plot_dfs([as_df[[ 'System_Parameters.Input_Voltage','Battery_Level_Fitted']]])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
as_df_shuffled = as_df.sample(frac=1, random_state=42).reset_index(drop=True)

X = as_df_shuffled[features].copy()
y = as_df_shuffled[target].copy() 



len(X), len(y)
#X = as_df[features].copy()
#y = as_df[target].copy()
# Out:
# (452, 452)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, LSTM
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)


model = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {test_loss:.4f}, Test MAE: {test_mae:.4f}")

# Make predictions
y_pred = model.predict(X_test)

# Calculate performance metrics
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.4f}")

# Compute R² score
r2 = r2_score(y_test, y_pred)
print(f"R² Score: {r2:.4f}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 117.0965 - mae: 10.2202 - val_loss: 142.8315 - val_mae: 11.9457
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 143.0488 - mae: 11.9511 - val_loss: 141.6967 - val_mae: 11.8981
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 141.8576 - mae: 11.9012 - val_loss: 140.5190 - val_mae: 11.8485
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 141.2316 - mae: 11.8763 - val_loss: 139.2779 - val_mae: 11.7960
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 138.7493 - mae: 11.7696 - val_loss: 137.9545 - val_mae: 11.7398
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 137.9698 - mae: 11.7373 - val_loss: 136.5282 - val_mae: 11.6788
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 136.5710 - mae: 11.6764 - val_loss: 134.9882 - val_mae: 11.6127
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 134.6466 - mae: 11.5933 - val_loss: 133.3216 - val_mae: 11.5407
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 132.9403 - mae: 11.5208 - val_loss: 131.5195 - val_mae: 11.4624
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 131.2715 - mae: 11.4472 - val_loss: 129.5732 - val_mae: 11.3772
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 128.7233 - mae: 11.3354 - val_loss: 127.4807 - val_mae: 11.2849
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 127.2027 - mae: 11.2691 - val_loss: 125.2340 - val_mae: 11.1849
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 125.7711 - mae: 11.2054 - val_loss: 122.8337 - val_mae: 11.0770
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 122.2475 - mae: 11.0455 - val_loss: 120.2837 - val_mae: 10.9613
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 118.8553 - mae: 10.8909 - val_loss: 117.5814 - val_mae: 10.8374
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 117.0879 - mae: 10.8111 - val_loss: 114.7259 - val_mae: 10.7048
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 114.5976 - mae: 10.6959 - val_loss: 111.7296 - val_mae: 10.5639
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 110.9151 - mae: 10.5207 - val_loss: 108.6009 - val_mae: 10.4148
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 108.0912 - mae: 10.3852 - val_loss: 105.3420 - val_mae: 10.2572
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 103.9782 - mae: 10.1839 - val_loss: 101.9664 - val_mae: 10.0913
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 101.4737 - mae: 10.0633 - val_loss: 98.4803 - val_mae: 9.9170
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 96.8259 - mae: 9.8251 - val_loss: 94.9066 - val_mae: 9.7352
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 94.6442 - mae: 9.7184 - val_loss: 91.2450 - val_mae: 9.5453
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 90.6916 - mae: 9.5116 - val_loss: 87.5189 - val_mae: 9.3481
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 86.3351 - mae: 9.2795 - val_loss: 83.7446 - val_mae: 9.1440
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 83.1152 - mae: 9.1047 - val_loss: 79.9282 - val_mae: 8.9328
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 78.9547 - mae: 8.8719 - val_loss: 76.0958 - val_mae: 8.7157
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 75.0860 - mae: 8.6518 - val_loss: 72.2551 - val_mae: 8.4925
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 71.4620 - mae: 8.4398 - val_loss: 68.4242 - val_mae: 8.2639
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 67.3135 - mae: 8.1904 - val_loss: 64.6232 - val_mae: 8.0306
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 63.7082 - mae: 7.9680 - val_loss: 60.8565 - val_mae: 7.7925
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 59.7903 - mae: 7.7155 - val_loss: 57.1502 - val_mae: 7.5510
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 55.8493 - mae: 7.4565 - val_loss: 53.5143 - val_mae: 7.3063
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 52.3235 - mae: 7.2156 - val_loss: 49.9554 - val_mae: 7.0585
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 49.3802 - mae: 7.0120 - val_loss: 46.4867 - val_mae: 6.8084
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 45.7150 - mae: 6.7454 - val_loss: 43.1268 - val_mae: 6.5570
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.6428 - mae: 6.5121 - val_loss: 39.8824 - val_mae: 6.3047
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 39.2307 - mae: 6.2444 - val_loss: 36.7610 - val_mae: 6.0521
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 36.0114 - mae: 5.9818 - val_loss: 33.7729 - val_mae: 5.8000
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 33.1161 - mae: 5.7357 - val_loss: 30.9196 - val_mae: 5.5486
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.5438 - mae: 5.5050 - val_loss: 28.2063 - val_mae: 5.2985
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.5677 - mae: 5.2252 - val_loss: 25.6485 - val_mae: 5.0513
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 24.9820 - mae: 4.9742 - val_loss: 23.2336 - val_mae: 4.8063
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.7889 - mae: 4.7530 - val_loss: 20.9692 - val_mae: 4.5647
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.6991 - mae: 4.5278 - val_loss: 18.8522 - val_mae: 4.3266
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.6325 - mae: 4.2902 - val_loss: 16.8910 - val_mae: 4.0937
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.4152 - mae: 4.0235 - val_loss: 15.0769 - val_mae: 3.8658
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.6945 - mae: 3.8067 - val_loss: 13.4048 - val_mae: 3.6431
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.1379 - mae: 3.5922 - val_loss: 11.8718 - val_mae: 3.4262
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.6596 - mae: 3.3825 - val_loss: 10.4719 - val_mae: 3.2155
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.2291 - mae: 3.1599 - val_loss: 9.2058 - val_mae: 3.0122
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.0588 - mae: 2.9763 - val_loss: 8.0547 - val_mae: 2.8146
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9794 - mae: 2.7920 - val_loss: 7.0235 - val_mae: 2.6250
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8776 - mae: 2.5840 - val_loss: 6.1041 - val_mae: 2.4437
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.0417 - mae: 2.4164 - val_loss: 5.2820 - val_mae: 2.2692
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1397 - mae: 2.2224 - val_loss: 4.5572 - val_mae: 2.1034
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4550 - mae: 2.0645 - val_loss: 3.9173 - val_mae: 1.9454
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8609 - mae: 1.9161 - val_loss: 3.3563 - val_mae: 1.7954
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3346 - mae: 1.7784 - val_loss: 2.8670 - val_mae: 1.6536
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8004 - mae: 1.6212 - val_loss: 2.4442 - val_mae: 1.5203
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4978 - mae: 1.5209 - val_loss: 2.0750 - val_mae: 1.3937
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0685 - mae: 1.3841 - val_loss: 1.7602 - val_mae: 1.2757
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7194 - mae: 1.2508 - val_loss: 1.4905 - val_mae: 1.1656
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5113 - mae: 1.1700 - val_loss: 1.2608 - val_mae: 1.0670
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3232 - mae: 1.0861 - val_loss: 1.0661 - val_mae: 0.9752
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1303 - mae: 0.9949 - val_loss: 0.9001 - val_mae: 0.8890
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0078 - mae: 0.9350 - val_loss: 0.7623 - val_mae: 0.8101
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8214 - mae: 0.8374 - val_loss: 0.6476 - val_mae: 0.7382
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7430 - mae: 0.7828 - val_loss: 0.5523 - val_mae: 0.6745
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6211 - mae: 0.7162 - val_loss: 0.4733 - val_mae: 0.6176
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.5395 - mae: 0.6560 - val_loss: 0.4080 - val_mae: 0.5670
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4709 - mae: 0.6117 - val_loss: 0.3536 - val_mae: 0.5218
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4617 - mae: 0.5865 - val_loss: 0.3108 - val_mae: 0.4821
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3492 - mae: 0.5103 - val_loss: 0.2749 - val_mae: 0.4478
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3499 - mae: 0.5099 - val_loss: 0.2459 - val_mae: 0.4188
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3340 - mae: 0.4905 - val_loss: 0.2226 - val_mae: 0.3956
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3301 - mae: 0.4796 - val_loss: 0.2036 - val_mae: 0.3791
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2732 - mae: 0.4336 - val_loss: 0.1884 - val_mae: 0.3650
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2924 - mae: 0.4352 - val_loss: 0.1765 - val_mae: 0.3534
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2555 - mae: 0.4181 - val_loss: 0.1669 - val_mae: 0.3436
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2648 - mae: 0.4146 - val_loss: 0.1596 - val_mae: 0.3353
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2634 - mae: 0.4052 - val_loss: 0.1534 - val_mae: 0.3282
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2253 - mae: 0.3900 - val_loss: 0.1483 - val_mae: 0.3217
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2735 - mae: 0.4059 - val_loss: 0.1448 - val_mae: 0.3166
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2230 - mae: 0.3631 - val_loss: 0.1424 - val_mae: 0.3130
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2196 - mae: 0.3585 - val_loss: 0.1401 - val_mae: 0.3093
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2399 - mae: 0.3685 - val_loss: 0.1383 - val_mae: 0.3059
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2197 - mae: 0.3577 - val_loss: 0.1369 - val_mae: 0.3029
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2635 - mae: 0.3736 - val_loss: 0.1359 - val_mae: 0.3004
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2684 - mae: 0.3699 - val_loss: 0.1352 - val_mae: 0.2984
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2191 - mae: 0.3496 - val_loss: 0.1345 - val_mae: 0.2963
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2252 - mae: 0.3552 - val_loss: 0.1340 - val_mae: 0.2947
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2233 - mae: 0.3452 - val_loss: 0.1337 - val_mae: 0.2936
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2501 - mae: 0.3585 - val_loss: 0.1334 - val_mae: 0.2928
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1970 - mae: 0.3229 - val_loss: 0.1332 - val_mae: 0.2917
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2038 - mae: 0.3291 - val_loss: 0.1331 - val_mae: 0.2914
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1980 - mae: 0.3348 - val_loss: 0.1330 - val_mae: 0.2909
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2213 - mae: 0.3314 - val_loss: 0.1329 - val_mae: 0.2904
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2154 - mae: 0.3400 - val_loss: 0.1329 - val_mae: 0.2901
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2089 - mae: 0.3243 - val_loss: 0.1328 - val_mae: 0.2897
# Test Loss (MSE): 0.1328, Test MAE: 0.2897
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Mean Squared Error: 0.1328
# R² Score: -0.0009

# %% [markdown]
# ## loss

# %%
import matplotlib.pyplot as plt

# Plot Training & Validation Loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Test Values vs Predictions

# %%
plt.figure(figsize=(12, 6))

# Ensure y_test and y_pred are both NumPy arrays
y_test_np = y_test.to_numpy().flatten()  # Convert y_test to a NumPy array
y_pred_np = y_pred.flatten()  # Ensure predictions are also flattened

# Get the index from y_test to use for plotting
sample_indices = np.arange(len(y_test_np))  # Create a sequential index

# Plot actual test values
plt.plot(sample_indices, y_test_np, label="Actual Values", linestyle="none", marker=".", color="blue")

# Plot predicted values
plt.plot(sample_indices, y_pred_np, label="Predicted Values", linestyle="none", marker=".", color="red")

plt.xlabel("Sample Index")
plt.ylabel("Target Value")
plt.title("Actual vs Predicted Values")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(8, 6))

# Scatter plot of predictions vs actual values
plt.scatter(y_test, y_pred, alpha=0.5, label="Predicted vs Actual", color="blue")

# Perfect prediction line (y = x)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='dashed', label="Perfect Prediction")

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs Actual Values")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## prediction as

# %%
#seg_to_predict = Austevoll_Sor_df_segments[3][features].copy()
#seg_to_predict.head(5)

# %%
from feature_adder import inverse_transform
# inverse_transform(df: pd.DataFrame, column: str, scaler: Scaler)
segs_to_predict = [3,4,5,6,7,8,9]
for seg in segs_to_predict:
    seg_to_predict = Austevoll_Sor_df_segments[seg][features].copy()
    #seg_to_predict = scaler.transform(seg_to_predict)
    prediction = model.predict(seg_to_predict)
    plt.figure(figsize=(10, 5))
    plt.plot(Austevoll_Sor_df_segments[seg]['System_Parameters.Input_Voltage'].values, label='Actual Voltage (vo)')
    #plt.plot(Austevoll_Sor_df_segments[seg]['smooth_System_Parameters.Input_Voltage'].values, label='Actual Voltage (vs)', linestyle="none",marker=".")
    plt.plot(prediction, label='Predicted Voltage')
    plt.xlabel("Time Step")
    plt.ylabel("Voltage")
    plt.title(f"Voltage Predictions vs. Actual for Segment {seg}")
    plt.legend()
    plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''# Extract before transformation (keep as Series)
vo1 = Austevoll_Sor_df_segments[3]['System_Parameters.Input_Voltage'].values
v02 = Austevoll_Sor_df_segments[4]['System_Parameters.Input_Voltage'].values
vo3 = Austevoll_Sor_df_segments[5]['System_Parameters.Input_Voltage'].values
vo4 = Austevoll_Sor_df_segments[6]['System_Parameters.Input_Voltage'].values
vo5 = Austevoll_Sor_df_segments[7]['System_Parameters.Input_Voltage'].values
vo6 = Austevoll_Sor_df_segments[8]['System_Parameters.Input_Voltage'].values
vo7 = Austevoll_Sor_df_segments[9]['System_Parameters.Input_Voltage'].values

# Prepare data for prediction
seg_to_predict1 = Austevoll_Sor_df_segments[3][features].copy()
seg_to_predict1 = scaler.transform(seg_to_predict1)

seg_to_predict2 = Austevoll_Sor_df_segments[4][features].copy()
seg_to_predict2 = scaler.transform(seg_to_predict2)

seg_to_predict3 = Austevoll_Sor_df_segments[5][features].copy()
seg_to_predict3 = scaler.transform(seg_to_predict3)

seg_to_predict4 = Austevoll_Sor_df_segments[6][features].copy()
seg_to_predict4 = scaler.transform(seg_to_predict4)

seg_to_predict5 = Austevoll_Sor_df_segments[7][features].copy()
seg_to_predict5 = scaler.transform(seg_to_predict5)

seg_to_predict6 = Austevoll_Sor_df_segments[8][features].copy()
seg_to_predict6 = scaler.transform(seg_to_predict6)

seg_to_predict7 = Austevoll_Sor_df_segments[9][features].copy()
seg_to_predict7 = scaler.transform(seg_to_predict7)



# Make predictions
prediction1 = model.predict(seg_to_predict1)
prediction2 = model.predict(seg_to_predict2)
prediction3 = model.predict(seg_to_predict3)
prediction4 = model.predict(seg_to_predict4)
prediction5 = model.predict(seg_to_predict5)
prediction6 = model.predict(seg_to_predict6)
prediction7 = model.predict(seg_to_predict7)

# Plot Predictions
plt.figure(figsize=(10, 5))
#plt.plot(vo, label='Actual Voltage (vo)', linestyle="none",marker=".", color="blue")
plt.plot(prediction1, label='Predicted Voltage 1')
plt.plot(prediction2, label='Predicted Voltage 2')
plt.plot(prediction3, label='Predicted Voltage 3')
plt.plot(prediction4, label='Predicted Voltage 4')
plt.plot(prediction5, label='Predicted Voltage 5')
plt.plot(prediction6, label='Predicted Voltage 6')
plt.plot(prediction7, label='Predicted Voltage 7')

plt.xlabel("Time Step")
plt.ylabel("Voltage")
plt.title("Voltage Predictions vs. Actual")
plt.legend()
plt.show()
'''
# Out:
# '# Extract before transformation (keep as Series)\nvo1 = Austevoll_Sor_df_segments[3][\'System_Parameters.Input_Voltage\'].values\nv02 = Austevoll_Sor_df_segments[4][\'System_Parameters.Input_Voltage\'].values\nvo3 = Austevoll_Sor_df_segments[5][\'System_Parameters.Input_Voltage\'].values\nvo4 = Austevoll_Sor_df_segments[6][\'System_Parameters.Input_Voltage\'].values\nvo5 = Austevoll_Sor_df_segments[7][\'System_Parameters.Input_Voltage\'].values\nvo6 = Austevoll_Sor_df_segments[8][\'System_Parameters.Input_Voltage\'].values\nvo7 = Austevoll_Sor_df_segments[9][\'System_Parameters.Input_Voltage\'].values\n\n# Prepare data for prediction\nseg_to_predict1 = Austevoll_Sor_df_segments[3][features].copy()\nseg_to_predict1 = scaler.transform(seg_to_predict1)\n\nseg_to_predict2 = Austevoll_Sor_df_segments[4][features].copy()\nseg_to_predict2 = scaler.transform(seg_to_predict2)\n\nseg_to_predict3 = Austevoll_Sor_df_segments[5][features].copy()\nseg_to_predict3 = scaler.transform(seg_to_predict3)\n\nseg_to_predict4 = Austevoll_Sor_df_segments[6][features].copy()\nseg_to_predict4 = scaler.transform(seg_to_predict4)\n\nseg_to_predict5 = Austevoll_Sor_df_segments[7][features].copy()\nseg_to_predict5 = scaler.transform(seg_to_predict5)\n\nseg_to_predict6 = Austevoll_Sor_df_segments[8][features].copy()\nseg_to_predict6 = scaler.transform(seg_to_predict6)\n\nseg_to_predict7 = Austevoll_Sor_df_segments[9][features].copy()\nseg_to_predict7 = scaler.transform(seg_to_predict7)\n\n\n\n# Make predictions\nprediction1 = model.predict(seg_to_predict1)\nprediction2 = model.predict(seg_to_predict2)\nprediction3 = model.predict(seg_to_predict3)\nprediction4 = model.predict(seg_to_predict4)\nprediction5 = model.predict(seg_to_predict5)\nprediction6 = model.predict(seg_to_predict6)\nprediction7 = model.predict(seg_to_predict7)\n\n# Plot Predictions\nplt.figure(figsize=(10, 5))\n#plt.plot(vo, label=\'Actual Voltage (vo)\', linestyle="none",marker=".", color="blue")\nplt.plot(prediction1, label=\'Predicted Voltage 1\')\nplt.plot(prediction2, label=\'Predicted Voltage 2\')\nplt.plot(prediction3, label=\'Predicted Voltage 3\')\nplt.plot(prediction4, label=\'Predicted Voltage 4\')\nplt.plot(prediction5, label=\'Predicted Voltage 5\')\nplt.plot(prediction6, label=\'Predicted Voltage 6\')\nplt.plot(prediction7, label=\'Predicted Voltage 7\')\n\nplt.xlabel("Time Step")\nplt.ylabel("Voltage")\nplt.title("Voltage Predictions vs. Actual")\nplt.legend()\nplt.show()\n'

# %%
'''seg_to_predict = Austevoll_Sor_df_segments[seg_to_predict].copy()

seg_to_predict.loc[:, ['Time_Since_t0']] = scaler.fit_transform(seg_to_predict[['Time_Since_t0']])
seg_to_predict.loc[:, ['num_not_Nan']] = scaler.fit_transform(seg_to_predict[['num_not_Nan']])

X_to_predict = seg_to_predict[['Time_Since_t0', 'num_not_Nan']].copy()

y_to_predict = seg_to_predict['System_Parameters.Input_Voltage'].copy()

y_predicted = model.predict(X_to_predict)
mse = mean_squared_error(y_to_predict, y_predicted)
print(f"Mean Squared Error: {mse:.4f}")

plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_to_predict)), y_to_predict.values, label="Actual Values", marker='o')
plt.scatter(range(len(y_predicted)), y_predicted, label="Predicted Values", marker='x')
plt.title("Actual vs Predicted Values")
plt.xlabel("Sample Index")
plt.ylabel("System_Parameters.Input_Voltage")
plt.legend()
plt.grid()
plt.show()'''
# Out:
# 'seg_to_predict = Austevoll_Sor_df_segments[seg_to_predict].copy()\n\nseg_to_predict.loc[:, [\'Time_Since_t0\']] = scaler.fit_transform(seg_to_predict[[\'Time_Since_t0\']])\nseg_to_predict.loc[:, [\'num_not_Nan\']] = scaler.fit_transform(seg_to_predict[[\'num_not_Nan\']])\n\nX_to_predict = seg_to_predict[[\'Time_Since_t0\', \'num_not_Nan\']].copy()\n\ny_to_predict = seg_to_predict[\'System_Parameters.Input_Voltage\'].copy()\n\ny_predicted = model.predict(X_to_predict)\nmse = mean_squared_error(y_to_predict, y_predicted)\nprint(f"Mean Squared Error: {mse:.4f}")\n\nplt.figure(figsize=(10, 6))\nplt.scatter(range(len(y_to_predict)), y_to_predict.values, label="Actual Values", marker=\'o\')\nplt.scatter(range(len(y_predicted)), y_predicted, label="Predicted Values", marker=\'x\')\nplt.title("Actual vs Predicted Values")\nplt.xlabel("Sample Index")\nplt.ylabel("System_Parameters.Input_Voltage")\nplt.legend()\nplt.grid()\nplt.show()'

# %% [markdown]
# ## ausevoll nord

# %% [markdown]
# ### Get Data

# %%
Austevoll_Nord_file_path =  "row_data\\Austevoll_Nord\\Austevoll_data_instrument.feather"
print(Austevoll_Nord_file_path)
Austevoll_Nord_df = pd.read_feather(Austevoll_Nord_file_path)
Austevoll_Nord_df.set_index('Time', inplace=True)
len(Austevoll_Nord_df)
# Out:
# row_data\Austevoll_Nord\Austevoll_data_instrument.feather
# 24219

# %%
len(Austevoll_Nord_df.columns)
# Out:
# 26

# %%
for col in Austevoll_Nord_df.columns:
    print(col)
# Out:
# Long
# Lat
# Conductivity_Sensor.Conductivity
# Conductivity_Sensor.Temperature
# Conductivity_Sensor.Salinity
# Conductivity_Sensor.Density
# Conductivity_Sensor.Soundspeed
# Pressure_Sensor.Pressure
# Pressure_Sensor.Temperature
# Doppler_Current_Profiler_Sensor.Record_State
# Doppler_Current_Profiler_Sensor.Ping_Count
# System_Parameters.Input_Voltage
# System_Parameters.Memory_Used
# SeaBird_SBE.Temperature
# SeaBird_SBE.Conductivity
# SeaBird_SBE.Pressure
# SeaBird_SBE.Oxygen
# SeaBird_SBE.Sound_Velocity
# Doppler_Current_Profiler_Sensor.Heading
# Doppler_Current_Profiler_Sensor.Std_Dev_Heading
# Doppler_Current_Profiler_Sensor.Pitch
# Doppler_Current_Profiler_Sensor.Roll
# Doppler_Current_Profiler_Sensor.Abs_Tilt
# Doppler_Current_Profiler_Sensor.Max_Tilt
# Doppler_Current_Profiler_Sensor.Std_Dev_Tilt
# Doppler_Current_Profiler_Sensor.Tilt_Direction

# %%
an_list_segments = [1,2,3,4,5,6,7]
Austevoll_Nord_df_segments = setup_an_data(Austevoll_Nord_df, smooth_sigma=18, list_segments=an_list_segments, r_h=r_h)
# Out:
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.5244, b=48.3165, d=119.92, s=0.000000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.4753, b=17.1146, d=102.50, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.5593, b=18.0123, d=73.48, s=0.001000
# ✅ Fitted params: a=12.6001, b=24.4392, d=89.05, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.5366, b=18.2859, d=82.33, s=0.001000
# ✅ Fitted params: a=12.7593, b=24.8346, d=81.72, s=0.001000
# The provided DatetimeIndex was associated with a timezone, which is currently not supported by xarray. To avoid unexpected behaviour, the tz information was removed. Consider calling `ts.time_index.tz_localize(UTC)` when exporting the results.To plot the series with the right time steps, consider setting the matplotlib.pyplot `rcParams['timezone']` parameter to automatically convert the time axis back to the original timezone.
# ✅ Fitted params: a=12.3198, b=10.1417, d=49.77, s=0.001000

# %% [markdown]
# ## make data daily

# %%
Austevoll_Nord_df_segments_daily_max = {
    key: df.resample('24h').max()
    for key, df in Austevoll_Nord_df_segments.items()
}


for key in Austevoll_Nord_df_segments_daily_max:
    plot_dfs(
        [Austevoll_Nord_df_segments_daily_max[key][['System_Parameters.Input_Voltage']]],
        format='.',
        title=f"Segment {key} - Daily Max",
    )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Austevoll_Nord_df_segments = Austevoll_Nord_df_segments_daily_max.copy()

# %%
for i, df in Austevoll_Nord_df_segments.items():
    processed_df = process_segment(df)
    Austevoll_Nord_df_segments[i] = processed_df
# Out:
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)
# C:\Users\yfess\AppData\Local\Temp\ipykernel_6600\1077605561.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['dV_dt'].fillna(0, inplace=True)

# %% [markdown]
# ### Normalize input voltage for each segment using Scalar

# %%
from feature_adder import normalize_data

an_seg_scalers_iv = {}

for seg_key, seg_df in Austevoll_Nord_df_segments.items():
    seg_df, scaler_y = normalize_data(seg_df, 'System_Parameters.Input_Voltage')
    
    Austevoll_Nord_df_segments[seg_key] = seg_df
    
    an_seg_scalers_iv[seg_key] = scaler_y



an_seg_scalers_siv = {}
for seg_key, seg_df in Austevoll_Nord_df_segments.items():
    seg_df, scaler_y = normalize_data(seg_df, 'smooth_System_Parameters.Input_Voltage')
    
    Austevoll_Nord_df_segments[seg_key] = seg_df
    
    an_seg_scalers_siv[seg_key] = scaler_y
    
    
an_seg_scalers_week_sin = {}
for seg_key, seg_df in Austevoll_Nord_df_segments.items():
    seg_df, scaler_y = normalize_data(seg_df,  'sin_week')
    
    Austevoll_Nord_df_segments[seg_key] = seg_df
    
    an_seg_scalers_week_sin[seg_key] = scaler_y
    
an_seg_scalers_week_cos = {}
for seg_key, seg_df in Austevoll_Nord_df_segments.items():
    seg_df, scaler_y = normalize_data(seg_df,  'cos_week')
    
    Austevoll_Nord_df_segments[seg_key] = seg_df
    
    an_seg_scalers_week_cos[seg_key] = scaler_y
an_seg_scalers_iv, an_seg_scalers_siv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\yfess\Desktop\data\data_env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smooth_System_Parameters.Input_Voltage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 16
#      14 an_seg_scalers_siv = {}
#      15 for seg_key, seg_df in Austevoll_Nord_df_segments.items():
# ---> 16     seg_df, scaler_y = normalize_data(seg_df, 'smooth_System_Parameters.Input_Voltage')
#      18     Austevoll_Nord_df_segments[seg_key] = seg_df
#      20     an_seg_scalers_siv[seg_key] = scaler_y
#
# File c:\Users\yfess\Desktop\data\feature_adder.py:392, in normalize_data(df, column)
#     388 df_copy = df.copy()
#     390 scaler1 = Scaler()
# --> 392 v_i = df_copy[column]
#     393 y_n  = TimeSeries.from_series(v_i)
#     394 y_n = scaler1.fit_transform(y_n)
#
# File c:\Users\yfess\Desktop\data\data_env\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\yfess\Desktop\data\data_env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'smooth_System_Parameters.Input_Voltage'

# %% [markdown]
# ## prediction an

# %%
from feature_adder import inverse_transform
# inverse_transform(df: pd.DataFrame, column: str, scaler: Scaler)
segs_to_predict = [2,3,5,7]
#segs_to_predict = [1,2,3,4,5,6,7]
for seg in segs_to_predict:
    seg_to_predict = Austevoll_Nord_df_segments[seg][features].copy()
    #seg_to_predict = scaler.transform(seg_to_predict)
    prediction = model.predict(seg_to_predict)
    plt.figure(figsize=(10, 5))
    plt.plot(Austevoll_Nord_df_segments[seg]['System_Parameters.Input_Voltage'].values, label='Actual Voltage (vo)', linestyle="none",marker=".", color="blue")
    plt.plot(prediction, label='Predicted Voltage', linestyle="dashed", color="red")
    plt.xlabel("Time Step")
    plt.ylabel("Voltage")
    plt.title(f"Voltage Predictions vs. Actual for Segment {seg}")
    plt.legend()
    plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
